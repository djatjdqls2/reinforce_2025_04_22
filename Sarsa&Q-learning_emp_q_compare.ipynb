# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 로그 불러오기
01_logs = pd.read_csv('./logs/rewards_q_gamma01.csv', index_col=False).iloc[:, 1]
05_logs = pd.read_csv('./logs/rewards_q_gamma05.csv', index_col=False).iloc[:, 1]
09_logs = pd.read_csv('./logs/rewards_q_gamma09.csv', index_col=False).iloc[:, 1]
99_logs = pd.read_csv('./logs/rewards_q_gamma99.csv', index_col=False).iloc[:, 1]

# 에피소드 인덱스
episodes = range(len(sarsa_logs))

# 그래프 출력
plt.figure(figsize=(16, 8))
plt.plot(01_logs.cumsum() / (pd.Series(np.arange(01_logs.shape[0])) + 1), label="gamma=0.1")
plt.plot(05_logs.cumsum() / (pd.Series(np.arange(05_logs.shape[0])) + 1), label="gamma=0.1")
plt.plot(09_logs.cumsum() / (pd.Series(np.arange(09_logs.shape[0])) + 1), label="gamma=0.1")
plt.plot(99_logs.cumsum() / (pd.Series(np.arange(99_logs.shape[0])) + 1), label="gamma=0.1")
plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.title("Q-value Comparison")
plt.legend()
plt.grid(True)
plt.savefig("gamma_compare.jpg", dpi=300, bbox_inches='tight')
plt.show()
